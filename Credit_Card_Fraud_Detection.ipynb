# %% [markdown]
# <a href="https://colab.research.google.com/github/UdayKhunt/Machine-Learning-Projects/blob/main/Credit_Card_Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
credit_data = pd.read_csv('/content/drive/MyDrive/DataSets/creditcard.csv')

# %%
credit_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
credit_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit_data.shape
# Out:
# (284807, 31)

# %%
legit = credit_data[credit_data.Class == 0]
fraud = credit_data[credit_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
legit_sample=legit.sample(n=492)

# %%
new_data = pd.concat([legit_sample,fraud],axis=0)

# %%
new_data['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_data.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 179550  124130.0  2.042074 -0.058200 -1.163093  0.218613  0.133397 -0.689122
# 91688    63582.0  1.186083  1.198728 -1.496875  1.587972  0.729524 -1.639790
# 216236  140398.0  2.083538 -1.184200 -0.114653 -0.888588 -1.262610  0.011613
# 162859  115437.0  1.902459 -0.825118 -1.386335 -0.639154  1.485058  4.033977
# 80900    58706.0  1.496372 -1.082734  0.817348 -1.314089 -1.848752 -0.805565
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 179550  0.123630 -0.208071  0.195548  ... -0.250253 -0.587064  0.279527
# 91688   0.632389 -0.213033 -0.613391  ... -0.152269 -0.414286 -0.188892
# 216236 -1.411139  0.097157  0.374560  ...  0.273846  0.782617  0.260286
# 162859 -1.443234  1.133233  1.406348  ...  0.081757  0.264077  0.289810
# 80900  -1.256066 -0.137329 -1.586425  ... -0.060598  0.234895 -0.000323
#
# ...

# %%
X=new_data.drop(['Class'],axis=1)
Y=new_data['Class']

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,random_state=4,test_size=.2,stratify=Y)

# %%
model = LogisticRegression()
model.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train)
X_train_accuracy = accuracy_score(X_train_prediction , Y_train)
print(X_train_accuracy)
# Out:
# 0.9479034307496823

# %%
X_test_prediction = model.predict(X_test)
X_test_accuracy = accuracy_score(X_test_prediction , Y_test)
print(X_test_accuracy)
# Out:
# 0.9289340101522843
